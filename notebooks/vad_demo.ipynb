# %% [markdown]
# # Context-aware speech understanding
#
# Upload a recorded household scene, or record one, then let the pipeline
# decide per utterance whether it is the command, relevant context, or noise.
#
# 1. **Start world** builds the environment the robot acts in. Wait for
#    "World ready" before continuing.
# 2. Record or upload a clip, then **Understand scene**.
# 3. **Plan and execute** hands the resulting instruction to the planner.

# %%
from vad_ui import run_vad_ui

run_vad_ui()
