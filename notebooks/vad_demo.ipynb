# %% [markdown]
# # Context-aware speech understanding
#
# Upload a recorded household scene (one clip, possibly several speakers).
# The pipeline segments it, transcribes each utterance, groups voices, and
# decides per utterance whether it is the command, relevant context, or noise.
# The resulting single instruction goes to the planner; execution is handled
# by the running `thesis_demo` action server.
#
# Start the action server first (it also writes the world context this UI reads):
# ```
# python -m thesis_demo.action_server
# ```

# %%
from vad_ui import run_vad_ui

run_vad_ui()
